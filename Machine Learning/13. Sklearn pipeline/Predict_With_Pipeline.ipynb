# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
# Assume User Imput
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 0.5, 'S'], dtype = object).reshape(1, 7)

# %%
import pandas as pd
test_input = pd.DataFrame(test_input)
test_input.columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
test_input
# Out:
#   Pclass   Sex   Age SibSp Parch Fare Embarked
# 0      2  male  31.0     0     0  0.5        S

# %%
pipe.predict(test_input)
# Out:
# array([0])

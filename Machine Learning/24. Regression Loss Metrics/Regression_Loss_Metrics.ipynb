# %% [markdown]
# # Regression Metrics
#
# #### 1. MAE (Mean Absolute Error)
# #### 2. MSE (Mean Squared Error)
# #### 3. RMSE (Root Mean Squared Error)
# #### 4. R2-Score
# #### 5. Adjusted R2-Score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (in LPA)')
# Out:
# Text(0, 0.5, 'Package (in LPA)')

# %%
X = df.iloc[:, 0].values.reshape(-1, 1)
y = df.iloc[:, 1].values.reshape(-1, 1)

# %%
X
# Out:
# array([[6.89],
#        [5.12],
#        [7.82],
#        [7.42],
#        [6.94],
#        [7.89],
#        [6.73],
#        [6.75],
#        [6.09],
#        [8.31],
#        [5.32],
#        [6.61],
#        [8.94],
#        [6.93],
#        [7.73],
#        [7.25],
#        [6.84],
#        [5.38],
#        [6.94],
#        [7.48],
#        [7.28],
#        [6.85],
#        [6.14],
#        [6.19],
#        [6.53],
#        [7.28],
#        [8.31],
#        [5.42],
#        [5.94],
#        [7.15],
#        [7.36],
#        [8.1 ],
#        [6.96],
#        [6.35],
#        [7.34],
#        [6.87],
#        [5.99],
#        [5.9 ],
#        [8.62],
#        [7.43],
#        [9.38],
#        [6.89],
#        [5.95],
#        [7.66],
#        [5.09],
#        [7.87],
#        [6.07],
#        [5.84],
#        [8.63],
#        [8.87],
#        [9.58],
#        [9.26],
#        [8.37],
#        [6.47],
#        [6.86],
#        [8.2 ],
#        [5.84],
#        [6.6 ],
# ...

# %%
y
# Out:
# array([[3.26],
#        [1.98],
#        [3.25],
#        [3.67],
#        [3.57],
#        [2.99],
#        [2.6 ],
#        [2.48],
#        [2.31],
#        [3.51],
#        [1.86],
#        [2.6 ],
#        [3.65],
#        [2.89],
#        [3.42],
#        [3.23],
#        [2.35],
#        [2.09],
#        [2.98],
#        [2.83],
#        [3.16],
#        [2.93],
#        [2.3 ],
#        [2.48],
#        [2.71],
#        [3.65],
#        [3.42],
#        [2.16],
#        [2.24],
#        [3.49],
#        [3.26],
#        [3.89],
#        [3.08],
#        [2.73],
#        [3.42],
#        [2.87],
#        [2.84],
#        [2.43],
#        [4.36],
#        [3.33],
#        [4.02],
#        [2.7 ],
#        [2.54],
#        [2.76],
#        [1.86],
#        [3.58],
#        [2.26],
#        [3.26],
#        [4.09],
#        [4.62],
#        [4.43],
#        [3.79],
#        [4.11],
#        [2.61],
#        [3.09],
#        [3.39],
#        [2.74],
#        [1.94],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test
# Out:
# array([[4.1 ],
#        [3.49],
#        [2.08],
#        [2.33],
#        [1.94],
#        [1.48],
#        [1.86],
#        [3.09],
#        [4.21],
#        [2.87],
#        [3.65],
#        [4.  ],
#        [2.89],
#        [2.6 ],
#        [2.99],
#        [3.25],
#        [1.86],
#        [3.67],
#        [2.37],
#        [3.42],
#        [2.48],
#        [3.65],
#        [2.6 ],
#        [2.83],
#        [4.08],
#        [2.56],
#        [3.58],
#        [3.81],
#        [4.09],
#        [2.01],
#        [3.63],
#        [2.92],
#        [3.51],
#        [1.94],
#        [2.21],
#        [3.34],
#        [3.34],
#        [3.23],
#        [2.01],
#        [2.61]])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
r2 = r2_score(y_test, y_pred)
print("R2-Score", r2)
# Out:
# R2-Score 0.780730147510384

# %% [markdown]
# ## Adjusted R2-Score

# %%
n = X_test.shape[0]
k = X_test.shape[1]
print('Adjusted R2 Score', 1-((1-r2)*(n-1))/(n-1-k))
# Out:
# Adjusted R2 Score 0.7749598882343415

# %% [markdown]
# ## Check the effect of Adding a column on Adjusted R2-Score
#
#
# #### 1. Adding non-essential column

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.683878     3.26
# 1  5.12        0.168502     1.98
# 2  7.82        0.488692     3.25
# 3  7.42        0.753753     3.67
# 4  6.94        0.876575     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2 = r2_score(y_test,y_pred)
print("R2 score",r2)
# Out:
# R2 score 0.7794873736698027

# %%
n = X_test.shape[0]
k = X_test.shape[1]
print('Adjusted R2 Score', 1-((1-r2)*(n-1))/(n-1-k))
# Out:
# Adjusted R2 Score 0.7675677722465488

# %% [markdown]
# #### 2. Adding essential column

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 154  7.08  2.55     2.85
# 97   5.98  2.84     2.84
# 87   8.09  3.75     3.55
# 165  8.21  4.48     4.08
# 15   7.25  2.63     3.23

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# 67

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
r2 = r2_score(y_test,y_pred)
print("R2 score",r2)
# Out:
# R2 score 0.7921308162525673

# %%
n = X_test.shape[0]
k = X_test.shape[1]
print('Adjusted R2 Score', 1-((1-r2)*(n-1))/(n-1-k))
# Out:
# Adjusted R2 Score 0.7808946441581115
